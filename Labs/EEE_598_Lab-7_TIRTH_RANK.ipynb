# %% [markdown]
# # Atmospheric Turbulence Image Generation
#
# [Link to the Repository](https://github.com/Riponcs/QuickTurbSim)
#
# [Paper with Demo Link](https://riponcs.github.io/TurbSegRes/)

# %%
# !git clone https://github.com/Riponcs/QuickTurbSim.git
# Out:
# Cloning into 'QuickTurbSim'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 24 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 3.76 MiB | 10.21 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd QuickTurbSim/
# !pip install noise
# Out:
# /content/QuickTurbSim
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for noise: filename=noise-1.2.2-cp312-cp312-linux_x86_64.whl size=56633 sha256=ded7a35705f4fbfe5cecc83df1b1d6c79938d0d6e5b829818c0d23586339be40
#   Stored in directory: /root/.cache/pip/wheels/78/71/a2/47a0c6acdeb8f7a2f4e69067d3c737219e36414136441a1ef8
# Successfully built noise
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !pwd #It shoulld show /content/QuickTurbSim
# Out:
# /content

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread('/content/QuickTurbSim/input/stripe.jpg')), plt.title('Input Image used for simulation'), plt.show();

# %%
# !ls
# Out:
# QuickTurbSim  sample_data

# %%
cd QuickTurbSim/
# Out:
# /content/QuickTurbSim

# %%
# Let's run the code. It will take input from input folder and save those images in Simulated_images folder
# !python RunQuickTurbSim.py
# Out:
# 100% 10/10 [00:00<00:00, 39.83it/s]
# 100% 10/10 [00:05<00:00,  1.90it/s]
#   0% 0/10 [00:00<?, ?it/s][ WARN:0@12.029] global loadsave.cpp:1063 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# 100% 10/10 [00:00<00:00, 41.71it/s]
# Took 12.20s to generate 1 videos with 10 frames each. Resolution 512x512

# %%
plt.imshow(plt.imread('/content/QuickTurbSim/Simulated_Images/frame_00000_0000.png')), plt.title('Output Image generated by simulation'), plt.show();

# %% [markdown]
# ## Quiz - Let's simulate an images with less turbulence on an image you like

# %%
# Hints - Open RunQuickTurbSim.py and change config based on the readme.
